# %%
import sympy as sp
from IPython.display import display, Math

def display_large(expr):
    """Display a sympy expression in LaTeX with large font size."""
    display(Math(r"\large{%s}" % sp.latex(expr)))

def display_huge(expr):
    """Display a sympy expression in LaTeX with huge font size."""
    display(Math(r"\huge{%s}" % sp.latex(expr)))

# %%
#1
z1 = sp.sympify('3 + 4*i')
z2 = sp.sympify('1 - 2*i')
result = z1 + z2
result
# Out:
# 2*i + 4

# %%
#2

#(2-3j)-(5+7j)

(2-3*sp.I)-(5+7*sp.I)
# Out:
# -3 - 10*I

# %%
#3
#(1+2j)(2+5j)


z = sp.sympify('1+2j') * sp.sympify('2+5j')
sp.simplify(z)
# Out:
# -8 + 9*I

# %%
#4

z = sp.sympify('7+6j') / sp.sympify('3-2j')
sp.simplify(z)
# Out:
# 9/13 + 32*I/13

# %%
#5 (4-5j)+(2+3j)

(4-5*sp.I)+(2+3*sp.I)
# Out:
# 6 - 2*I

# %%
#6

#(6+j)-(3-4j)

(6+sp.I)-(3-4*sp.I)
# Out:
# 3 + 5*I

# %%
#7

sp.simplify( sp.sympify('3-1j') * sp.sympify('2+4j') )
# Out:
# 10 + 10*I

# %%
#8

sp.simplify( sp.sympify('5+5j') / sp.sympify('1+2j') )
# Out:
# 3 - I

# %%
#9

sp.simplify( sp.sympify("(2+3j)^2") )
# Out:
# -5 + 12*I

# %%
#10


sp.expand( (1-sp.I)**3 )
# Out:
# -2 - 2*I

# %%
#11

z = 3+4*sp.I

display( sp.conjugate(z) )

display( sp.Abs(z) )

display( sp.arg(z) )
# Out:
# 3 - 4*I
# 5
# atan(4/3)

# %%
#12

z = -3+4*sp.I

display( sp.conjugate(z) )

display( sp.Abs(z) )

display( sp.arg(z) )
# Out:
# -3 - 4*I
# 5
# pi - atan(4/3)

# %%
#13

z = 1-1*sp.I

display( sp.conjugate(z) )

display( sp.Abs(z) )

display( sp.arg(z) )
# Out:
# 1 + I
# sqrt(2)
# -pi/4

# %%
#14

z = -2-2*sp.I

display( sp.conjugate(z) )

display( sp.Abs(z) )

display( sp.arg(z) )
# Out:
# -2 + 2*I
# 2*sqrt(2)
# -3*pi/4

# %%
#15

z = 5*sp.I

display( sp.conjugate(z) )

display( sp.Abs(z) )

display( sp.arg(z) )
# Out:
# -5*I
# 5
# pi/2

# %%
#16

z = -7

display( sp.conjugate(z) )

display( sp.Abs(z) )

display( sp.arg(z) )
# Out:
# -7
# 7
# pi

# %%
#17

z = 1+sp.I

display_huge( sp.Abs(z)*sp.exp(sp.I*sp.arg(z)) )
# Out:
# $\displaystyle \huge{\sqrt{2} e^{\frac{i \pi}{4}}}$

# %%
#18

z = -1+sp.I

display_huge( sp.Abs(z)*sp.exp(sp.I*sp.arg(z)) )
# Out:
# $\displaystyle \huge{\sqrt{2} e^{\frac{3 i \pi}{4}}}$

# %%
#19

z = 2-2*sp.I

display_huge( sp.Abs(z)*sp.exp(sp.I*sp.arg(z)) )
# Out:
# $\displaystyle \huge{2 \sqrt{2} e^{- \frac{i \pi}{4}}}$

# %%
#20

z = -3

display_huge( sp.Abs(z)*sp.exp(sp.I*sp.arg(z)) )
# Out:
# $\displaystyle \huge{-3}$

# %%
#21

z = (1+sp.I)**4

display_huge( sp.Abs(z)*sp.exp(sp.I*sp.arg(z)) )
# Out:
# $\displaystyle \huge{-4}$

# %%
#22

z = (-1+sp.I)**3

sp.expand(z)
# Out:
# 2 + 2*I

# %%
#23
z = 1*sp.exp(sp.I*(sp.pi/3) )
display_huge( z )

z_cartesian = sp.expand_complex(z)
z_cartesian
# Out:
# $\displaystyle \huge{e^{\frac{i \pi}{3}}}$
# 1/2 + sqrt(3)*I/2

# %%
#24

z = 2*sp.exp(sp.I*(sp.pi/4) )
display_huge( z )

z_cartesian = sp.expand_complex(z)
z_cartesian
# Out:
# $\displaystyle \huge{2 e^{\frac{i \pi}{4}}}$
# sqrt(2) + sqrt(2)*I

# %%
#25

z = sp.symbols('z')


solutions = sp.solve(z**2 - sp.I, z)

for sol in solutions:
    display( sp.expand_complex(sol) )
# Out:
# -sqrt(2)/2 - sqrt(2)*I/2
# sqrt(2)/2 + sqrt(2)*I/2

# %%
#26

z = sp.symbols('z')


solutions = sp.solve(z**3 - (-1), z)

for sol in solutions:
    display( sp.expand_complex(sol) )
# Out:
# -1
# 1/2 - sqrt(3)*I/2
# 1/2 + sqrt(3)*I/2

# %%
#27

z = sp.symbols('z')


solutions = sp.solve(z**2 - (1+sp.I), z)

for sol in solutions:
    display_huge( sp.expand_complex(sol) )
# Out:
# $\displaystyle \huge{- \sqrt[4]{2} \sqrt{\frac{\sqrt{2}}{4} + \frac{1}{2}} - \sqrt[4]{2} i \sqrt{\frac{1}{2} - \frac{\sqrt{2}}{4}}}$
# $\displaystyle \huge{\sqrt[4]{2} \sqrt{\frac{\sqrt{2}}{4} + \frac{1}{2}} + \sqrt[4]{2} i \sqrt{\frac{1}{2} - \frac{\sqrt{2}}{4}}}$

# %%
#28

z = sp.symbols('z')

solutions = sp.solve(z**2 + (1 - 2*sp.I)*z + 5, z)
for sol in solutions:
    display_huge(sp.expand_complex(sol))
# Out:
# $\displaystyle \huge{- \frac{1}{2} - \frac{\sqrt[4]{545} \sin{\left(\frac{\operatorname{atan}{\left(\frac{4}{23} \right)}}{2} \right)}}{2} + i \left(1 + \frac{\sqrt[4]{545} \cos{\left(\frac{\operatorname{atan}{\left(\frac{4}{23} \right)}}{2} \right)}}{2}\right)}$
# $\displaystyle \huge{- \frac{1}{2} + \frac{\sqrt[4]{545} \sin{\left(\frac{\operatorname{atan}{\left(\frac{4}{23} \right)}}{2} \right)}}{2} + i \left(- \frac{\sqrt[4]{545} \cos{\left(\frac{\operatorname{atan}{\left(\frac{4}{23} \right)}}{2} \right)}}{2} + 1\right)}$

# %%
#29


z = sp.symbols('z')

solutions = sp.solve(z**2 - 2*z + 2, z)
for sol in solutions:
    display(sp.expand_complex(sol))
# Out:
# 1 - I
# 1 + I

# %%
#30


z = sp.symbols('z')
solutions = sp.solve(z**2 + 4, z)
for sol in solutions:
    display(sp.expand_complex(sol))
# Out:
# -2*I
# 2*I

# %%
#31

z = sp.symbols('z')
# Define j as the imaginary unit (compatible with sympy's I)
j = sp.I
# Define the quadratic equation: z^2 - (3 + j)z + (2 + 2j) = 0
solutions = sp.solve(z**2 - (3 + j)*z + (2 + 2*j), z)
for sol in solutions:
    display(sp.expand_complex(sol))
# Out:
# 2
# 1 + I

# %%
# Define matrices A and B
A = sp.Matrix([[1 + 2*sp.I], [3 - 4*sp.I], [-2 + 2*sp.I]])
B = sp.Matrix([[-1 + 2*sp.I], [2 + 2*sp.I], [3]])

# %%
#32
A+B
# Out:
# Matrix([
# [    4*I],
# [5 - 2*I],
# [1 + 2*I]])

# %%
#33

sp.simplify( A.multiply_elementwise(B) )
# Out:
# Matrix([
# [      -5],
# [14 - 2*I],
# [-6 + 6*I]])

# %%
#34

sp.Abs(A)
# Out:
# Matrix([
# [  sqrt(5)],
# [        5],
# [2*sqrt(2)]])

# %%
#35

A.conjugate()
# Out:
# Matrix([
# [ 1 - 2*I],
# [ 3 + 4*I],
# [-2 - 2*I]])

# %%
#36

sp.simplify( A.dot( B.conjugate() ) )
# Out:
# -5 - 12*I

# %%
#37

A-B
# Out:
# Matrix([
# [       2],
# [ 1 - 6*I],
# [-5 + 2*I]])

# %%
C = sp.Matrix([
    [1 + sp.I, 2],
    [3 - sp.I, 1 + 2*sp.I]
])

display(C)


v = sp.Matrix([
    [1 + sp.I],
    [2 - sp.I]
])

display(v)
# Out:
# Matrix([
# [1 + I,       2],
# [3 - I, 1 + 2*I]])
# Matrix([
# [1 + I],
# [2 - I]])

# %%
#38
C.det()
# Out:
# -7 + 5*I

# %%
#39

sp.simplify( C*v )
# Out:
# Matrix([
# [      4],
# [8 + 5*I]])

# %%
#40

sp.Abs(3-4*sp.I)
# Out:
# 5

# %%
#41

sp.Abs(3-4*sp.I) * sp.conjugate( sp.Abs(3-4*sp.I) )
# Out:
# 25

# %%
#42

z = 1 + sp.I
result = sp.log(sp.Abs(z)) + sp.I * sp.arg(z)
display(result)
# Out:
# log(sqrt(2)) + I*pi/4

# %%
#43

sp.sqrt(3+4*sp.I)
# Out:
# 2 + I

# %%
#44


sp.expand_complex( 1/(2-3*sp.I) )
# Out:
# 2/13 + 3*I/13

# %%
#45

j = sp.I

sp.expand_complex( ( (1+2*j)+(3-j) )/( 1-j) )
# Out:
# 3/2 + 5*I/2

# %%
#46

x, y = sp.symbols('x y', real=True)

# explain why equation |z - 1| = 2 to be
expr = sp.Eq(sp.sqrt((x-1)**2 + y**2), 2)

display(expr)

# To plot using sympy.plot_implicit:
sp.plot_implicit(expr, (x, -3, 5), (y, -3, 3), 
                 xlabel="Re(z)", ylabel="Im(z)", 
                 title=r"Plot of $|z-1|=2$", 
                 line_color='blue', show=True, aspect_ratio=(1,1))
# Out:
# Eq(sqrt(y**2 + (x - 1)**2), 2)

# %%
#47

# Draw the vertical line Re(z) = 3 using sympy (i.e., x = 3)
expr_re3 = sp.Eq(x, 3)
display(expr_re3)

sp.plot_implicit(expr_re3, (x, -3, 5), (y, -3, 3),
                 xlabel="Re(z)", ylabel="Im(z)",
                 title=r"Plot of $\operatorname{Re}(z) = 3$",
                 line_color='red', show=True, aspect_ratio=(1, 1))
# Out:
# Eq(x, 3)

# %%
#48

# Draw the horizontal line Im(z) = -1 using sympy (i.e., y = -1)
expr_im_neg1 = sp.Eq(y, -1)
display(expr_im_neg1)

sp.plot_implicit(expr_im_neg1, (x, -3, 5), (y, -3, 3),
                 xlabel="Re(z)", ylabel="Im(z)",
                 title=r"Plot of $\operatorname{Im}(z) = -1$",
                 line_color='green', show=True, aspect_ratio=(1, 1))
# Out:
# Eq(y, -1)

# %%
#49

# Draw the locus where |z| = |z - 2|, i.e., the set of points in the complex plane where the distance to 0 equals the distance to 2.
# This is the perpendicular bisector of the segment joining 0 and 2, i.e., Re(z) = 1.

expr_eq = sp.Eq(sp.sqrt(x**2 + y**2), sp.sqrt((x - 2)**2 + y**2))

display(expr_eq)

sp.plot_implicit(expr_eq, (x, -3, 5), (y, -3, 3),
                 xlabel="Re(z)", ylabel="Im(z)",
                 title=r"Plot of $|z| = |z-2|$",
                 line_color='purple', show=True, aspect_ratio=(1, 1))
# Out:
# Eq(sqrt(x**2 + y**2), sqrt(y**2 + (x - 2)**2))

# %%
#50

#Step 1
x, y = sp.symbols('x y', positive=True)

# Step 2: Define the original equation
eq = sp.Eq(sp.arg(x + y * sp.I), sp.pi/4)
print("Original Equation:")
display(eq)

# Step 3: Rewrite the argument using tan/inverse trig functions
# SymPy will automatically simplify arg(x + iy) to atan2(y, x)
eq_rewritten = eq.rewrite(sp.atan2)
display(eq_rewritten)

# Step 4: Apply tangent to both sides to clear the atan2 function
# sp.tan(sp.atan2(y, x)) simplifies directly to y/x when x > 0
eq_tan = sp.Eq(sp.tan(eq_rewritten.lhs), sp.tan(eq_rewritten.rhs))
display(eq_tan)

# Step 5: Solve for y to get the final equation form
final_eq = sp.solve(eq_tan, y, dict=True)[0]
output_eq = sp.Eq(y, final_eq[y])

print("\nResulting Equation:")
display(output_eq)
# Out:
# Original Equation:
# Eq(arg(x + I*y), pi/4)
# Eq(atan(y/x), pi/4)
# Eq(y/x, 1)
# Resulting Equation:
# Eq(y, x)

# %%
#51

sp.atan2(1,-1)
# Out:
# 3*pi/4

# %%
#52

sp.atan2(-3,-2)
# Out:
# -pi + atan(3/2)

# %%
#53

sp.atan2(-5,0)
# Out:
# -pi/2

# %%
#54

sp.atan2( -4, 4)
# Out:
# -pi/4

# %%
#55

sp.atan2( 0,-5 )
# Out:
# pi

# %%
#56

x, y = sp.symbols('x y', positive=True)

z = sp.cos(x)+sp.I*sp.sin(x)

display_huge( z.rewrite(sp.exp) )
# Out:
# $\displaystyle \huge{e^{i x}}$

# %%
#57

x, y = sp.symbols('x y', positive=True)

z = sp.cos(x)

display_huge( z.rewrite(sp.exp) )
# Out:
# $\displaystyle \huge{\frac{e^{i x}}{2} + \frac{e^{- i x}}{2}}$

# %%
#58

x, y = sp.symbols('x y', positive=True)

z = sp.sin(x)

display_huge( z.rewrite(sp.exp) )
# Out:
# $\displaystyle \huge{- \frac{i \left(e^{i x} - e^{- i x}\right)}{2}}$

# %%
#59

x, y = sp.symbols('x y', positive=True)

z = sp.cosh(x)

display_huge( z.rewrite(sp.exp) )
# Out:
# $\displaystyle \huge{\frac{e^{x}}{2} + \frac{e^{- x}}{2}}$

# %%
#60

x, y = sp.symbols('x y', positive=True)

z = sp.sinh(x)

display_huge( z.rewrite(sp.exp) )
# Out:
# $\displaystyle \huge{\frac{e^{x}}{2} - \frac{e^{- x}}{2}}$
