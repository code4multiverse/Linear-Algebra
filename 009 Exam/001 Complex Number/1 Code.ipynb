# %%
import sympy as sp

# %%
#1
z1 = sp.sympify('3 + 4*i')
z2 = sp.sympify('1 - 2*i')
result = z1 + z2
result
# Out:
# 2*i + 4

# %%
#2

#(2-3j)-(5+7j)

(2-3*sp.I)-(5+7*sp.I)
# Out:
# -3 - 10*I

# %%
#3
#(1+2j)(2+5j)


z = sp.sympify('1+2j') * sp.sympify('2+5j')
sp.simplify(z)
# Out:
# -8 + 9*I

# %%
#4

z = sp.sympify('7+6j') / sp.sympify('3-2j')
sp.simplify(z)
# Out:
# 9/13 + 32*I/13

# %%
#5 (4-5j)+(2+3j)

(4-5*sp.I)+(2+3*sp.I)
# Out:
# 6 - 2*I
